# %%
import pandas as pd
df = pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df['country'].value_counts()
# Out:
# United States                                                   2555
# India                                                            923
# United Kingdom                                                   397
# Japan                                                            226
# South Korea                                                      183
#                                                                 ...
# Russia, United States, China                                       1
# Italy, Switzerland, France, Germany                                1
# United States, United Kingdom, Canada                              1
# United States, United Kingdom, Japan                               1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: country, Length: 681, dtype: int64

# %%
df['country'].value_counts()[:3]
# Out:
# United States     2555
# India              923
# United Kingdom     397
# Name: country, dtype: int64

# %%
df.country.value_counts()
# Out:
# United States                                                   2555
# India                                                            923
# United Kingdom                                                   397
# Japan                                                            226
# South Korea                                                      183
#                                                                 ...
# Russia, United States, China                                       1
# Italy, Switzerland, France, Germany                                1
# United States, United Kingdom, Canada                              1
# United States, United Kingdom, Japan                               1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: country, Length: 681, dtype: int64

# %%
df.country.value_counts().head(3).to_dict()
# Out:
# {'United States': 2555, 'India': 923, 'United Kingdom': 397}

# %%
df.country.value_counts()[0:3].to_dict()
# Out:
# {'United States': 2555, 'India': 923, 'United Kingdom': 397}

# %%
df.release_year.value_counts().sort_index(ascending=False).head(10).to_dict()
# Out:
# {2021: 31,
#  2020: 868,
#  2019: 996,
#  2018: 1121,
#  2017: 1012,
#  2016: 882,
#  2015: 541,
#  2014: 334,
#  2013: 267,
#  2012: 219}

# %%
df["release_year"].value_counts().sort_index(ascending=False)[:10]
# Out:
# 2021      31
# 2020     868
# 2019     996
# 2018    1121
# 2017    1012
# 2016     882
# 2015     541
# 2014     334
# 2013     267
# 2012     219
# Name: release_year, dtype: int64

# %%
df.director.head(10).to_list()
# Out:
# [nan,
#  'Jorge Michel Grau',
#  'Gilbert Chan',
#  'Shane Acker',
#  'Robert Luketic',
#  'Serdar Akar',
#  'Yasir Al Yasiri',
#  'Kevin Reynolds',
#  'Shravan Kumar',
#  'Vikram Bhatt']

# %%
df.director.dropna().head(10).to_list()
# Out:
# ['Jorge Michel Grau',
#  'Gilbert Chan',
#  'Shane Acker',
#  'Robert Luketic',
#  'Serdar Akar',
#  'Yasir Al Yasiri',
#  'Kevin Reynolds',
#  'Shravan Kumar',
#  'Vikram Bhatt',
#  'Zak Hilditch']

# %%
dir(df.director.dropna().head(10))
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df[df['duration'].str.contains('min')]['duration']
# Out:
# 1        93 min
# 2        78 min
# 3        80 min
# 4       123 min
# 6        95 min
#          ...
# 7781     88 min
# 7782     99 min
# 7783    111 min
# 7784     44 min
# 7786     90 min
# Name: duration, Length: 5377, dtype: object

# %%
df.duration.str.contains('min')
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7782     True
# 7783     True
# 7784     True
# 7785    False
# 7786     True
# Name: duration, Length: 7787, dtype: bool

# %%
la_duree = df[df['duration'].str.contains('min')]['duration']
la_duree.str.replace(' min', '').map(int).mean()
# Out:
# 99.30797842663195

# %%
la_duree = df[df['duration'].str.contains(' min')]['duration']
la_duree.str.replace(' min', '').map(int).mean()
# Out:
# 99.30797842663195
